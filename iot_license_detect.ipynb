# %%
from ultralytics import YOLO
# Out:
# C:\Users\samar\anaconda3\envs\tf-gpu-spyder\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\samar\anaconda3\envs\tf-gpu-spyder\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\samar\anaconda3\envs\tf-gpu-spyder\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# Load a model
model = YOLO("yolov8s.pt")  # build a new model from scratch

# Use the model
results = model.train(data="license.yaml", epochs=25)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.0.220 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.199  Python-3.9.16 torch-2.0.0+cpu CPU (11th Gen Intel Core(TM) i7-1165G7 2.80GHz)
# ...
